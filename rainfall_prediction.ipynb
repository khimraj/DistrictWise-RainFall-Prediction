# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("datafile.csv")

# %%
df.head()
# Out:
#                       STATE/UT       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  JAN+FEB  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#      MAM    JJAS    OND
# 0  540.7  1207.2  892.1
# 1  483.5  1757.2  705.3
# ...

# %%
df.rename(columns={'JAN+FEB':'JF'}, inplace=True)

# %%
df.sort_values(by=['STATE/UT', 'DISTRICT'],inplace=True)

# %%
df.head()
# Out:
#                         STATE/UT       DISTRICT    JAN   FEB   MAR    APR  \
# 2    ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9   8.6   53.4
# 0    ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9  65.2  117.0
# 1    ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0  18.6   90.5
# 546               ANDHRA PRADESH       ADILABAD    7.5   7.0  11.4   11.9
# 556               ANDHRA PRADESH      ANANTAPUR    3.0   3.3   6.1   18.9
#
#        MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF  \
# 2    343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3   48.6
# 0    358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2  165.2
# 1    374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7   69.7
# 546   18.2  178.4  317.4  291.7  171.4   83.0   14.8    7.3  1120.0   14.5
# 556   56.7   55.2   64.3   74.5  128.8  115.0   35.3   11.6   572.7    6.3
#
#        MAM    JJAS    OND
# 2    405.6  1884.4  574.7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 640 entries, 2 to 107
# Data columns (total 19 columns):
# STATE/UT    640 non-null object
# DISTRICT    640 non-null object
# JAN         640 non-null float64
# FEB         640 non-null float64
# MAR         640 non-null float64
# APR         640 non-null float64
# MAY         640 non-null float64
# JUN         640 non-null float64
# JUL         640 non-null float64
# AUG         640 non-null float64
# SEP         640 non-null float64
# OCT         640 non-null float64
# NOV         640 non-null float64
# DEC         640 non-null float64
# ANNUAL      640 non-null float64
# JF          640 non-null float64
# MAM         640 non-null float64
# JJAS        640 non-null float64
# OND         640 non-null float64
# dtypes: float64(17), object(2)
# memory usage: 100.0+ KB

# %%
df.isnull().sum()
# Out:
# STATE/UT    0
# DISTRICT    0
# JAN         0
# FEB         0
# MAR         0
# APR         0
# MAY         0
# JUN         0
# JUL         0
# AUG         0
# SEP         0
# OCT         0
# NOV         0
# DEC         0
# ANNUAL      0
# JF          0
# MAM         0
# JJAS        0
# OND         0
# dtype: int64

# %%
df.describe()
# Out:
#               JAN         FEB         MAR         APR         MAY  \
# count  640.000000  640.000000  640.000000  640.000000  640.000000
# mean    18.351250   20.994219   30.063281   45.537969   81.394219
# std     21.099075   27.750169   45.480904   71.612125  111.991086
# min      0.000000    0.000000    0.000000    0.000000    0.900000
# 25%      6.875000    7.000000    7.000000    5.000000   12.100000
# 50%     13.300000   12.300000   12.700000   15.050000   33.850000
# 75%     19.125000   24.100000   33.275000   48.075000   91.825000
# max    144.500000  229.600000  367.900000  554.400000  733.700000
#
#                JUN          JUL          AUG         SEP         OCT  \
# count   640.000000   640.000000   640.000000  640.000000  640.000000
# mean    195.797656   326.093594   291.267344  194.658281   90.342187
# std     196.638268   221.532589   152.738890   99.900836   75.002933
# min       3.800000    11.600000    14.100000    8.600000    3.100000
# ...

# %%
month_df = df[['STATE/UT', 'DISTRICT', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL']]
month_group_df = df[['STATE/UT', 'DISTRICT', 'JF', 'MAM', 'JJAS', 'OND', 'ANNUAL']]
annual_df = df[['STATE/UT', 'DISTRICT', 'ANNUAL']]

# %%
state_ut_list = df.groupby('STATE/UT').sum().index.tolist()

# %%
plot = df.hist(figsize=(24,24))
for ax in plot.flatten():
    ax.set_xlabel("RainFall in MM")
    ax.set_ylabel("Frequency")
plt.savefig('Plot/Average RainFall Histogram Month-wise', dpi=300, bbox_inches='tight')

# %% [markdown]
# Observations:
# 1. Shows the distribution of rainfall over months.
# 2. Increase in amount of rainfall over months July, August, September.

# %%
plot = df.mean().plot(figsize=(13, 8));
plt.xticks(range(len(df.mean().index)), df.mean().index)
plt.title('Average Annual RainFall Month-wise', fontsize=15, weight='bold')
plt.ylabel('RainFall in MM', fontsize=15, weight='bold')
plt.xlabel('MONTH', fontsize=15, weight='bold')
plt.show()
fig = plot.get_figure()
fig.savefig('Plot/Average Annual RainFall Month-wise', dpi=300, bbox_inches='tight')

# %% [markdown]
# Observations:
# 1. Highest rainfall in month of July.
# 2. Highest rainfall in month group June, July, August and September.

# %%
plot = annual_df.groupby('STATE/UT')['ANNUAL'].mean().plot(figsize=(12,8))
plt.xticks(range(len(state_ut_list)), state_ut_list,rotation=90)
plt.title('STATE/UT Average Annual RainFall', fontsize=15, weight='bold')
plt.ylabel('RainFall in MM', fontsize=15, weight='bold')
plt.xlabel('STATE/UT', fontsize=15, weight='bold')
plt.show()
fig = plot.get_figure()
fig.savefig('Plot/STATE_UT Average Annual RainFall', dpi=300, bbox_inches='tight')

# %% [markdown]
# Observations:
# 1. Highest annual rainfall in Meghalaya State.
# 2. Least annual rainfall in Rajasthan State.

# %%
plot = annual_df.plot(kind='box',sharex=False,sharey=False)
plt.title('Annual RainFall Box Plot', fontsize=15, weight='bold')
plt.ylabel('RainFall in MM')
plt.show()
fig = plot.get_figure()
fig.savefig('Plot/Annual RainFall Box Plot', dpi=300, bbox_inches='tight')

# %% [markdown]
# Observations:
# 1. Median of annual rainfall in all districts is around 1000 mm.
# 2. There are very less number of districts having annual rainfall greater than 3000 mm.

# %%
plot = sns.violinplot(data = annual_df)
plt.title('Annual RainFall Violin Plot', fontsize=15, weight='bold')
plt.ylabel('RainFall in MM')
plt.show()
fig = plot.get_figure()
fig.savefig('Plot/Annual RainFall Violin Plot', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots()
annual_df.hist(ax=ax)
plt.title('STATE/UT Annual RainFall Histogram', fontsize=15, weight='bold')
plt.ylabel('Frequency', fontsize=15, weight='bold')
plt.xlabel('RainFall in MM', fontsize=15, weight='bold')
plt.show()
fig.savefig('Plot/Annual RainFall Histogram', dpi=300, bbox_inches='tight')

# %% [markdown]
# Observations:
# 1. Annual rainfall in most of districts is around 1000 mm.
# 2. There is significant number of districts having annual rainfall between 1500 mm and 3500 mm.

# %%
plot = month_df.groupby('STATE/UT').mean().plot(figsize=(13,8));
plt.xticks(range(len(state_ut_list)), state_ut_list, rotation=90)
plt.title('STATE/UT Average RainFall Month-wise', fontsize=15, weight='bold')
plt.ylabel('RainFall in MM', fontsize=15, weight='bold')
plt.xlabel('STATE/UT', fontsize=15, weight='bold')
plt.legend(bbox_to_anchor=(1,1))
plt.show()
fig = plot.get_figure()
fig.savefig('Plot/STATE_UT Average RainFall Month wise', dpi=300, bbox_inches='tight')

# %% [markdown]
# Observations:
# 1. Almost in all states maximum rainfall is in July month.
# 2. In Pondicherry there is more rainfall in October and November than in July.

# %%
plot = month_group_df.groupby('STATE/UT').mean().plot(figsize=(13,8));
plt.xticks(range(len(state_ut_list)), state_ut_list, rotation=90)
plt.title('STATE/UT Average RainFall MonthGroup-wise', fontsize=15, weight='bold')
plt.ylabel('RainFall in MM', fontsize=15, weight='bold')
plt.xlabel('STATE/UT', fontsize=15, weight='bold')
plt.legend(bbox_to_anchor=(1,1))
plt.show()
fig = plot.get_figure()
fig.savefig('Plot/STATE_UT Average RainFall MonthGroup wise', dpi=300, bbox_inches='tight')

# %% [markdown]
# Observations:
# 1. Almost in all states maximum rainfall is in June, July, August and September month group.
# 2. Almost in all states minimum rainfall is in January and February month group.
# 3. In Pondicherry and Tamilnadu rainfall in OND month group is greater than JJAS month group.
# 4. In east states there is significant rainfall in MAM month group.

# %%
plot = month_df.groupby("STATE/UT").mean().plot.barh(stacked=True, figsize=(13,8))
plt.title('STATE/UT Average RainFall Month-wise', fontsize=15, weight='bold')
plt.ylabel('STATE/UT', fontsize=15, weight='bold')
plt.xlabel('RainFall in MM', fontsize=15, weight='bold')
plt.legend(bbox_to_anchor=(1,1))
plt.show()
fig = plot.get_figure()
fig.savefig('Plot/STATE_UT Average RainFall Month wise Bar Graph', dpi=300, bbox_inches='tight')

# %% [markdown]
# Observations:
# 1. There is significant rainfall in all 12 months in Andaman and Nicobar Islands and Arunachal Pradesh.
# 2. There is significant rainfall in January month in Jammu and Kashmir and Himachal.

# %%
plot = month_group_df.groupby("STATE/UT").mean().plot.barh(stacked=True, figsize=(13,8))
plt.title('STATE/UT Average RainFall MonthGroup-wise', fontsize=15, weight='bold')
plt.ylabel('STATE/UT', fontsize=15, weight='bold')
plt.xlabel('RainFall in MM', fontsize=15, weight='bold')
plt.legend(bbox_to_anchor=(1,1))
plt.show()
fig = plot.get_figure()
fig.savefig('Plot/STATE_UT Average RainFall MonthGroup wise BarGraph', dpi=300, bbox_inches='tight')

# %% [markdown]
# Observations:
# 1. Almost in all states maximum rainfall is in JJAS month group.
# 2. In Pondicherry and Andman and Nicobar Islands rainfall in OND month group is highest.

# %%
for i in range(len(state_ut_list)):
    state_month_df = month_df.loc[df['STATE/UT']==state_ut_list[i]]
    plot = state_month_df.plot.barh(stacked=True, figsize=(13,max(len(state_month_df['DISTRICT'])/4,4)))
    plt.yticks(range(len(state_month_df['DISTRICT'])), state_month_df['DISTRICT'])
    plt.title(state_ut_list[i] + ' All District RainFall Month-wise', fontsize=15, weight='bold')
    plt.ylabel('DISTRICT', fontsize=15, weight='bold')
    plt.xlabel('RainFall in MM', fontsize=15, weight='bold')
    plt.legend(bbox_to_anchor=(1,1))
    plt.show()
    fig = plot.get_figure()
    fig.savefig('State-Wise Plot/' + state_ut_list[i] + ' Districts RainFall Month wise Bar Graph', dpi=300, bbox_inches='tight')
    
    state_month_group_df = month_group_df.loc[df['STATE/UT']==state_ut_list[i]]
    plot = state_month_group_df.plot.barh(stacked=True, figsize=(13,max(len(state_month_group_df['DISTRICT'])/4, 2)))
    plt.yticks(range(len(state_month_group_df['DISTRICT'])), state_month_group_df['DISTRICT'])
    plt.title(state_ut_list[i] + ' All District RainFall MonthGroup-wise', fontsize=15, weight='bold')
    plt.ylabel('DISTRICT', fontsize=15, weight='bold')
    plt.xlabel('RainFall in MM', fontsize=15, weight='bold')
    plt.legend(bbox_to_anchor=(1,1))
    plt.show()
    fig = plot.get_figure()
    fig.savefig('State-Wise Plot/' + state_ut_list[i] + ' Districts RainFall MonthGroup wise Bar Graph', dpi=300, bbox_inches='tight')

# %%
plt.figure(figsize=(11,4))
plot = sns.heatmap(month_df.corr(),annot=True)
plt.title('STATE/UT RainFall Correlation Month-wise', fontsize=15, weight='bold')
plt.show()
fig = plot.get_figure()
fig.savefig('Plot/STATE_UT RainFall Correlation Month-wise', dpi=300, bbox_inches='tight')

# %%
plt.figure(figsize=(11,4))
plot = sns.heatmap(month_group_df.corr(),annot=True)
plt.title('STATE/UT RainFall Correlation Month-wise', fontsize=15, weight='bold')
plt.show()
fig = plot.get_figure()
fig.savefig('Plot/STATE_UT RainFall Correlation MonthGroup-wise', dpi=300, bbox_inches='tight')

# %% [markdown]
# Observations:
# 1. shows co-relation between the amounts of rainfall over months.
# 2. Annual rainfall is highly dependent on rainfall in May, June, July, August and September.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

data = np.array(df[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']])

X = None 
y = None

prev_months = 2

for i in range(data.shape[1] - prev_months):
    if X is None:
        X = data[:, i : i + prev_months]
        y = data[:, i + prev_months]
    else:
        X = np.concatenate((X, data[:, i : i + prev_months]), axis=0)
        y = np.concatenate((y, data[:, i + prev_months]), axis=0)
        
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
rajasthan_data = df[['DISTRICT','JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL','AUG', 'SEP', 'OCT', 'NOV', 'DEC']].loc[df['STATE/UT'] == 'RAJASTHAN']
jalore_data = np.array(rajasthan_data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL','AUG', 'SEP', 'OCT', 'NOV', 'DEC']].loc[rajasthan_data['DISTRICT'] == 'JALORE'])

jalore_X = None 
jalore_y = None

prev_months = 2

for i in range(jalore_data.shape[1] - prev_months):
    if jalore_X is None:
        jalore_X = jalore_data[:, i : i + prev_months]
        jalore_y = jalore_data[:, i + prev_months]
    else:
        jalore_X = np.concatenate((jalore_X, jalore_data[:, i : i + prev_months]), axis=0)
        jalore_y = np.concatenate((jalore_y, jalore_data[:, i + prev_months]), axis=0)

# %%
#Function to plot the graphs
def plot_graphs(actual, predicted, title):
    fig = plt.figure(figsize=(13, 8))
    plt.plot(actual)
    plt.plot(predicted)
    plt.title(title, fontsize=15, weight='bold')
    plt.ylabel('RainFall in MM', fontsize=15, weight='bold')
    plt.xlabel('MONTH', fontsize=15, weight='bold')
    plt.xticks(range(10), ['MAR', 'APR', 'MAY', 'JUN', 'JUL','AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
    plt.legend(['Actual','Predicted'], loc='upper right')
    plt.show()
    fig.savefig('Plot/' + title, dpi=300, bbox_inches='tight')

# %%
from sklearn.linear_model import Lasso

# Lasso Regression model
reg = Lasso(alpha=0.1)
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)
mean_absolute_error(y_test, y_pred)
# Out:
# 54.968120766457545

# %%
jalore_y_pred = reg.predict(jalore_X)
mean_absolute_error(jalore_y, jalore_y_pred)
# Out:
# 47.39761637954713

# %%
plot_graphs(jalore_y, jalore_y_pred, 'Lasso Regression Model: Jalore RainFall Predication')

# %%
import tensorflow as tf

# 1D CNN model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv1D(filters=32, kernel_size=1, activation='relu', input_shape=(prev_months,1)))
model.add(tf.keras.layers.Conv1D(filters=64, kernel_size=1, activation='relu'))
model.add(tf.keras.layers.Conv1D(filters=128, kernel_size=1, activation='relu'))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(32, activation='relu'))
model.add(tf.keras.layers.Dense(1,activation = 'linear'))
opt = tf.keras.optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d (Conv1D)              (None, 2, 32)             64
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2, 64)             2112
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 2, 128)            8320
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# ...

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model.fit(X_train, y_train, batch_size=32, epochs=10, validation_split=0.2, shuffle=True)
y_pred = model.predict(X_test)
mean_absolute_error(y_test, y_pred)
# Out:
# Train on 3584 samples, validate on 896 samples
# Epoch 1/10
# 3584/3584 [==============================] - 1s 383us/sample - loss: 9350.2128 - mae: 56.3947 - val_loss: 6895.8653 - val_mae: 50.4781
# Epoch 2/10
# 3584/3584 [==============================] - 1s 228us/sample - loss: 9786.6122 - mae: 56.1329 - val_loss: 7043.1436 - val_mae: 50.6697
# Epoch 3/10
# 3584/3584 [==============================] - 1s 223us/sample - loss: 7846.2836 - mae: 53.2076 - val_loss: 6367.5721 - val_mae: 47.9345
# Epoch 4/10
# 3584/3584 [==============================] - 1s 229us/sample - loss: 8762.3485 - mae: 56.2723 - val_loss: 5988.8455 - val_mae: 48.2496
# Epoch 5/10
# 3584/3584 [==============================] - 1s 195us/sample - loss: 7255.1043 - mae: 50.9481 - val_loss: 6336.0885 - val_mae: 51.7718
# Epoch 6/10
# 3584/3584 [==============================] - 1s 219us/sample - loss: 6650.2754 - mae: 48.4468 - val_loss: 6755.2232 - val_mae: 47.8992
# Epoch 7/10
# ...

# %%
jalore_X = jalore_X.reshape(jalore_X.shape[0], jalore_X.shape[1], 1)
jalore_y_pred = model.predict(jalore_X)
mean_absolute_error(jalore_y, jalore_y_pred)
# Out:
# 33.121874256134035

# %%
plot_graphs(jalore_y, jalore_y_pred, '1D CNN Model: Jalore RainFall Predication')

# %%
# LSTM model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.LSTM(64, activation='relu', return_sequences=True, input_shape=(prev_months,1)))
model.add(tf.keras.layers.LSTM(32, activation='relu'))
model.add(tf.keras.layers.Dense(1))
opt = tf.keras.optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mae'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 2, 64)             16896
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# ...
# Total params: 29,345
# Trainable params: 29,345
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size=32, epochs=10, validation_split=0.2, shuffle=True)
y_pred = model.predict(X_test)
mean_absolute_error(y_test, y_pred)
# Out:
# Train on 3584 samples, validate on 896 samples
# Epoch 1/10
# 3584/3584 [==============================] - 4s 1ms/sample - loss: 9599.1485 - mae: 58.8524 - val_loss: 6787.1991 - val_mae: 48.5227
# Epoch 2/10
# 3584/3584 [==============================] - 1s 188us/sample - loss: 6181.0826 - mae: 46.4783 - val_loss: 5462.5486 - val_mae: 43.8048
# Epoch 3/10
# 3584/3584 [==============================] - 1s 237us/sample - loss: 6374.0268 - mae: 47.5830 - val_loss: 5591.0152 - val_mae: 42.8390
# Epoch 4/10
# 3584/3584 [==============================] - 1s 197us/sample - loss: 5976.8063 - mae: 45.1161 - val_loss: 5803.3104 - val_mae: 44.6468
# Epoch 5/10
# 3584/3584 [==============================] - 1s 184us/sample - loss: 7006.0890 - mae: 48.5321 - val_loss: 5378.1958 - val_mae: 43.6363
# Epoch 6/10
# 3584/3584 [==============================] - 1s 187us/sample - loss: 6126.6188 - mae: 46.4607 - val_loss: 5398.1356 - val_mae: 45.3221
# Epoch 7/10
# ...

# %%
jalore_y_pred = model.predict(jalore_X)
mean_absolute_error(jalore_y, jalore_y_pred)
# Out:
# 30.08075267791748

# %%
plot_graphs(jalore_y, jalore_y_pred, 'LSTM Model: Jalore RainFall Predication')
